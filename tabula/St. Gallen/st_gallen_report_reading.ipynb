# %% [markdown]
# # Data extraction for one city for one year

# %% [markdown]
# ## From the PDF with the income statement data of the city of St. Gallen (year 2022) till the final dataframe and the excel file

# %% [markdown]
# #### Importing the needed libraries

# %%
from tabula import read_pdf
import pandas as pd
from PyPDF2 import PdfWriter, PdfReader

# %% [markdown]
# ## 1. Importing the income statements from one year for one municipality

# %%
df = read_pdf("2022 SG.pdf", pages="all")

# %%
# This cell aims to show that df is a list of DFs: one DF per page extracted from the document

print(type(df)) # it is a list 
print(len(df)) # of 4 elements

print(df[0]) # the single DFs is what we are looking for
print(len(df[0])) # the lenght is also correct
# Out:
# <class 'list'>
# 4
#    Erfolgsrechnung nach Kostenart Alle DirektionenRechnung Budget
# 0                                           2021 2022              \
# 1                             667 662 996 676 632 100
# 2                            669 234 686 -654 888 370
# 3                              -1 571 690  21 743 730
# 4                             264 728 060 273 568 210
# 5                                 2 709 454 1 867 310
# 6                             144 538 179 143 738 970
# 7                               68 680 690 67 865 300
# 8                                             889 730
# 9                                   844 506 8 801 740
# 10                              39 799 252 40 945 200
# 11                                5 245 198 5 956 230
# 12                                2 910 781 3 503 730
# 13                              82 390 279 91 265 930
# 14                              10 462 247 12 651 940
# 15                                5 369 902 7 331 850
# 16                                5 221 948 5 659 470
# 17                              21 750 502 23 953 050
# 18                              18 835 743 19 232 180
# 19                                8 099 794 8 954 190
# 20                                5 554 585 5 593 980
# 21                                1 690 208 3 061 680
# 22                                4 077 818 3 359 010
# 23                                1 327 532 1 468 580
# 24                              41 298 400 25 731 310
# 25                              39 298 400 24 259 900
# 26                                2 000 000 1 471 410
# 27                              16 308 919 14 481 510
# 28                               9 895 638 10 365 010
# 29                                   3 028 348 10 000
# 30                                      47 038 64 000
# 31                                3 337 895 4 042 500
# 32                                                NaN
#
#    Nachtragskredit  Unnamed: 0  Konto
# 0             2022         NaN    NaN  \
# 1       69 858 232         NaN    NaN
# 2              NaN         NaN    NaN
# 3       69 858 232         NaN    NaN
# 4        1 929 450         NaN   30.0
# 5              NaN         NaN  300.0
# 6        1 666 500         NaN  301.0
# 7              NaN         NaN  302.0
# 8          103 920         NaN  303.0
# 9           19 000         NaN  304.0
# 10          55 300         NaN  305.0
# 11             NaN         NaN  306.0
# 12          84 730         NaN  309.0
# 13       8 274 285         NaN   31.0
# 14         843 250         NaN  310.0
# 15         688 045         NaN  311.0
# 16       1 792 900         NaN  312.0
# 17       2 295 600         NaN  313.0
# 18         450 080         NaN  314.0
# 19         447 250         NaN  315.0
# 20       1 414 170         NaN  316.0
# 21         303 130         NaN  317.0
# 22          10 400         NaN  318.0
# 23          27 360         NaN  319.0
# 24      31 912 090         NaN   33.0
# 25      29 111 790         NaN  330.0
# 26       2 800 300         NaN  332.0
# 27      15 172 450         NaN   34.0
# 28             NaN         NaN  340.0
# 29          19 100         NaN  341.0
# 30             NaN         NaN  342.0
# 31         673 300         NaN  343.0
# 32      14 480 050         NaN  344.0
#
#                                            Unnamed: 1   Rechnung 2022
# 0                                                 NaN   AufwandErtrag  \
# 1                                             Aufwand  806 710 659.40
# 2                                              Ertrag  802 024 241.24
# 3       Aufwandüberschuss (+) / Ertragsüberschuss (-)    4 686 418.16
# 4                                     Personalaufwand  261 488 439.52
# 5                           Behörden und Kommissionen    1 732 456.22
# 6        Löhne des Verwaltungs- und Betriebspersonals  140 219 925.58
# 7                              Löhne der Lehrpersonen   66 722 589.59
# 8                             Temporäre Arbeitskräfte      352 033.05
# 9                                             Zulagen    8 878 288.55
# 10                                Arbeitgeberbeiträge   39 781 095.05
# 11                              Arbeitgeberleistungen      574 783.16
# 12                            Übriger Personalaufwand    3 227 268.32
# 13                  Sach- und übriger Betriebsaufwand   87 567 262.20
# 14                         Material- und Warenaufwand   12 221 751.97
# 15                         Nicht aktivierbare Anlagen    5 914 294.56
# 16              Ver- und Entsorgung Liegenschaften VV    7 344 214.39
# 17                      Dienstleistungen und Honorare   22 509 359.19
# 18              Baulicher und betrieblicher Unterhalt   18 231 450.01
# 19        Unterhalt Mobilien und immaterielle Anlagen    8 478 678.52
# 20  Mieten, Leasing, Pachten, Benützungskostengebü...    5 956 780.26
# 21                              Spesenentschädigungen    2 769 027.69
# 22                 Wertberichtigungen auf Forderungen    3 269 744.30
# 23                            Übriger Betriebsaufwand      871 961.31
# 24                 Abschreibungen Verwaltungsvermögen   45 650 209.83
# 25                      Abschreibungen Sachanlagen VV   41 893 202.36
# 26                Abschreibungen immaterielle Anlagen    3 757 007.47
# 27                                      Finanzaufwand   34 256 710.56
# 28                                        Zinsaufwand    9 573 732.06
# 29                        Realisierte Kursverluste FV       20 624.60
# 30         Kapitalbeschaffungs- und Verwaltungskosten       59 006.29
# 31               Liegenschaftenaufwand Finanzvermögen    4 721 786.16
# 32                      Wertberichtigungen Anlagen FV   19 880 850.00
#
#     Unnamed: 2        Abweichung
# 0          NaN  RG / BU inkl. NK
# 1          NaN        60 220 327
# 2          NaN      -147 135 871
# 3          NaN       166 146 612
# 4          NaN       -14 009 220
# 5          NaN          -134 854
# 6          NaN        -5 185 544
# 7          NaN        -1 142 710
# 8          NaN          -641 617
# 9          NaN            57 549
# 10         NaN        -1 219 405
# 11         NaN        -5 381 447
# 12         NaN          -361 192
# 13         NaN       -11 972 953
# 14         NaN        -1 273 438
# 15         NaN        -2 105 600
# 16         NaN          -108 156
# 17         NaN        -3 739 291
# 18         NaN        -1 450 810
# 19         NaN          -922 761
# 20         NaN        -1 051 370
# 21         NaN          -595 782
# 22         NaN           -99 666
# 23         NaN          -623 979
# 24         NaN       -11 993 190
# 25         NaN       -11 478 488
# 26         NaN          -514 703
# 27         NaN         4 602 751
# 28         NaN          -791 278
# 29         NaN            -8 475
# 30         NaN            -4 994
# 31         NaN             5 986
# 32         NaN         5 400 800
# 33

# %% [markdown]
# #### After understanding the shape of what we have imported, we can see that we have a list of dataframes (4 in our case, so one per page)

# %%
print(df[0].head())
# Out:
#   Erfolgsrechnung nach Kostenart Alle DirektionenRechnung Budget
# 0                                          2021 2022              \
# 1                            667 662 996 676 632 100
# 2                           669 234 686 -654 888 370
# 3                             -1 571 690  21 743 730
# 4                            264 728 060 273 568 210
#
#   Nachtragskredit  Unnamed: 0  Konto
# 0            2022         NaN    NaN  \
# 1      69 858 232         NaN    NaN
# 2             NaN         NaN    NaN
# 3      69 858 232         NaN    NaN
# 4       1 929 450         NaN   30.0
#
#                                       Unnamed: 1   Rechnung 2022  Unnamed: 2
# 0                                            NaN   AufwandErtrag         NaN  \
# 1                                        Aufwand  806 710 659.40         NaN
# 2                                         Ertrag  802 024 241.24         NaN
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)    4 686 418.16         NaN
# 4                                Personalaufwand  261 488 439.52         NaN
#
#          Abweichung
# 0  RG / BU inkl. NK
# 1        60 220 327
# 2      -147 135 871
# 3       166 146 612
# 4       -14 009 220

# %%
print(df[0].columns)
# Out:
# Index(['Erfolgsrechnung nach Kostenart Alle DirektionenRechnung Budget',
#        'Nachtragskredit', 'Unnamed: 0', 'Konto', 'Unnamed: 1', 'Rechnung 2022',
#        'Unnamed: 2', 'Abweichung'],
#       dtype='object')

# %% [markdown]
# #### We can see that Tabula is good but not perfect. It also read the title displayed outside the frame of the table. To make things easier, we cut the pdf using the PyPDF2 library

# %% [markdown]
# ## 2. PDF cropping

# %%
# instantiating a reader object and reading its first page

reader = PdfReader("2022 SG.pdf", "r")
page = reader.pages[1]

# %%
# this is used to understand how the file is read by the PdfReader

print(page.mediabox) 

# N.B. although the PDF is displayed in the landscape format in Adobe DC, it has a vertical shape according to the numbers
# Out:
# RectangleObject([0, 0, 595.276, 841.89])

# %%
# instantiating a writer object

writer = PdfWriter()

# %%
# this code cuts every page of the pdf and saves them alltogehter in the writer object

for page in range(len(reader.pages)):
    single_page = reader.pages[page]
    # single_page.mediabox.upper_right = 500, 700
    single_page.mediabox.upper_left = 0, 800
    single_page.mediabox.lower_left = 0, 25
    writer.add_page(single_page)

# given the vertical orientation, the lowerleft and upperleft commands need to be used
# This instead of upperright, what had led to an unexpected output initially

# %%
# exporting the cropped PDF

export = open('2022 SG cropped.pdf', 'wb')
writer.write(export)
export.close()

# %% [markdown]
# #### Seeing that some of the PDFs (when going through all the ones from SG) got wrongly cropped, we need to take something into account

# %% [markdown]
# ## 3. Fixing cropping errors

# %%
# one of the PDFs wrongly cropped is the one from 2018

# reading it
reader_18 = PdfReader("2018 SG.pdf", "r")
page_18 = reader_18.pages[1]

# reading the base case report (2022 SG)
reader = PdfReader("2022 SG.pdf", "r")
page = reader.pages[1]

# %%
# how the one from 2018 is read         
print(page_18.mediabox, "\n") 

# vs how the 2022 was read
print(page.mediabox, "\n")
# Out:
# RectangleObject([0, 0, 642.283, 888.898])
#
# RectangleObject([0, 0, 595.276, 841.89])

# %% [markdown]
# #### The 2022 report was used as a base case to determine what parameters to use to successfully cut the PDF. That is how we need to adapt the "cutting" code

# %%
# coordinates of the base case (2022 report)
(LL_x_base, LL_y_base) = page.cropbox.lower_left
(UR_x_base, UR_y_base) = page.cropbox.upper_right

# %%
# coordinates of the specific year's report
(LL_x, LL_y) = page_18.cropbox.lower_left
(UR_x, UR_y) = page_18.cropbox.upper_right

# %%
# difference of the report's coordinates with the base case
D_LL_x = LL_x - LL_x_base
D_LL_y = LL_y - LL_y_base
D_UR_x = UR_x - UR_x_base
D_UR_y = UR_y - UR_y_base

# %%
# printing the difference
print(D_LL_x, D_LL_y, D_UR_x, D_UR_y)
# Out:
# 23.505 23.505 23.502 23.503

# %%
# writer object
writer = PdfWriter()

# %%
# adjusted "cutting" code
for page in range(len(reader_18.pages)):
    single_page = reader_18.pages[page]
    single_page.mediabox.lower_left = (0 + D_LL_x, 25 + D_LL_y)
    single_page.mediabox.upper_left = (0 + D_LL_x, 800 + D_UR_y)
    writer.add_page(single_page)

# %%
# exporting the cropped PDF

export = open('2018 SG cropped.pdf', 'wb')
writer.write(export)
export.close()

# %% [markdown]
# #### It worked, the coordinates of the base case report will be hardcoded in the python script used for all PDFs. Now we are left with the problem of the 2021 report being cut too little.

# %%
# reading the sizes of the 2021 SG report

# reading it
reader_21 = PdfReader("2021 SG.pdf", "r")
page_21 = reader_21.pages[1]

# how the 2021 is read
print(page_21.mediabox)
# Out:
# RectangleObject([23.5039, 23.504, 618.78, 865.394])

# %%
# rereading the base case report (2022 SG)
reader = PdfReader("2022 SG.pdf", "r")
page = reader.pages[1]

# coordinates of the base case (2022 report)
(LL_x_base, LL_y_base) = page.cropbox.lower_left
(UR_x_base, UR_y_base) = page.cropbox.upper_right

# coordinates of the specific year's report
(LL_x, LL_y) = page_21.cropbox.lower_left
(UR_x, UR_y) = page_21.cropbox.upper_right

# difference of the report's coordinates with the base case
D_LL_x_21 = LL_x - LL_x_base
D_LL_y_21 = LL_y - LL_y_base
D_UR_x_21 = UR_x - UR_x_base
D_UR_y_21 = UR_y - UR_y_base

# %%
# let's see the difference 
print(D_LL_x_21, D_LL_y_21, D_UR_x_21, D_UR_y_21)


# coordinates report
print("\nReport: ")
print(LL_x, LL_y)
print(UR_x, UR_y)

# coordinates base case (SG 2022)
print("\nBase case: ")
print(LL_x_base, LL_y_base)
print(UR_x_base, UR_y_base)
# Out:
# 0 0 47.007 47.008
#
# Report:
# 0 0
# 642.283 888.898
#
# Base case:
# 0 0
# 595.276 841.89

# %%
# given that we have different size values (when reading the 2021 pdf report),
# we need to adjust it in a different way. We cannot simply make a transfer of coordinates as before
# Let's calculate the factor by which this should happen
# that is on the x axis (UR_x / UR_x_base) and y axis (UR_y / UR_y_base)

factor_x =  UR_x / UR_x_base
factor_y = UR_y / UR_y_base

# %%
# this is by how much that difference should change
print(round(factor_x, 2), round(factor_y, 2))
# Out:
# 1.08 1.06

# %%
# writer object
writer = PdfWriter()

# %%
# adjusted "cutting" code
for page in range(len(reader_18.pages)):
    single_page = reader_18.pages[page]
    single_page.mediabox.upper_left = (0, 800 * factor_y)    
    single_page.mediabox.lower_left = (0, 25 * factor_y)
    writer.add_page(single_page)

# %%
# exporting the cropped PDF

export = open('2021 SG cropped.pdf', 'wb')
writer.write(export)
export.close()

# %%
# how the just cropped PDF is being read

reader_21 = PdfReader("2021 SG cropped.pdf", "r")
page_21 = reader_21.pages[1]

# how the 2021 cropped is read
print(page_21.mediabox)
# Out:
# RectangleObject([0, 26.39590682868308211286510115, 642.283, 844.6690185178586276116832368])

# %%
reader_base = PdfReader("2022 SG.pdf", "r")
reader_18 = PdfReader("2018 SG.pdf", "r")
reader_21 = PdfReader("2021 SG.pdf", "r")

# %%
reader = reader_21

# %%
## in the end the solution is to have a code that depends on whether that difference is constant or not.
## If so, there is a traslation. If not the factor is calculated

# base case
(LL_x_base, LL_y_base) = (0, 0)
(UR_x_base, UR_y_base) = (595.276, 841.89)

# difference from the base case report St. Gallen (reduced 2022 Rechnung). This report was used to determine the cutting coordinates
(LL_x, LL_y) = reader.pages[1].cropbox.lower_left
(UR_x, UR_y) = reader.pages[1].cropbox.upper_right

print((LL_x, LL_y))
print((UR_x, UR_y))

D_LL_x = round(float(LL_x) - LL_x_base)
D_LL_y = round(float(LL_y) - LL_y_base)
D_UR_x = round(float(UR_x) - UR_x_base)
D_UR_y = round(float(UR_y) - UR_y_base)

print(D_LL_x, D_LL_y, D_UR_x, D_UR_y)

if D_LL_x == D_LL_y == D_UR_x == D_UR_y:
    # print("all is equal")

    formula_UL = (0 + D_LL_x, 800 + D_UR_y)
    formula_LL = (0 + D_LL_x, 25 + D_LL_y)

else:
    factor_x =  float(UR_x) / UR_x_base
    factor_y = float(UR_y) / UR_y_base
    print(factor_x, factor_y)

    formula_UL = (0, 800 * factor_y)
    formula_LL = (0, 25 * factor_y)

# cutting every page of the PDF and saving them alltogehter in the writer object

writer = PdfWriter()

for page in range(len(reader.pages)):
    single_page = reader.pages[page]
    single_page.mediabox.upper_left = formula_UL
    single_page.mediabox.lower_left = formula_LL
    writer.add_page(single_page)

export = open("2021 SG cropped.pdf", 'wb')
writer.write(export)
export.close()
# Out:
# (0, 0)
# (642.283, 888.898)
# 0 0 47 47
# 1.0789667313985447 1.0558362731473234

# %% [markdown]
# #### The formula works and will be implemented in the overall data extraction script like that. The only issue is that the 2021 report got wrongly cut. The reason is that the report has not the same width / breadth ratio. Therefore, I will have to cut it manually. At least, the formula, should work for all forms that share the same ratio

# %%
## adding a code that knows the base ratio and raises an error in case of a different one
## to signal that the report needs a manual cut

base_ratio = round(841.89 / 595.276, 2)

print(base_ratio)
print(round(UR_y - LL_y, 2))
print(round(UR_x - LL_x, 2))
print(round((UR_y - LL_y) / (UR_x - LL_x), 2))

# if float(round((UR_y - LL_y) / (UR_x - LL_x), 2)) != base_ratio: # this cell was commented out, 
#     raise Exception("Different ratio!")                          # to allow the workbook to run fully
# Out:
# 1.41
# 888.90
# 642.28
# 1.38

# %%
## manual cropping of the 2021 report. Manual in the sense that different values are tried until it makes sense

writer = PdfWriter()

for page in range(len(reader_21.pages)):
    single_page = reader_21.pages[page]
    single_page.mediabox.lower_left = (0 , 48)
    single_page.mediabox.upper_left = (0 , 824.898)
    writer.add_page(single_page)

export = open("2021 SG cropped.pdf", 'wb')
writer.write(export)
export.close()

# %% [markdown]
# #### Now that the PDF got successfully cropped, we can reread it with Tabula and proceed

# %% [markdown]
# ## 4. Data manipulation with Tabula

# %%
df_tabula = read_pdf("2022 SG cropped.pdf", pages="all")

# %% [markdown]
# #### Analyzing input type and content

# %%
# lets analyze two single dfs
print(df_tabula[0].head())
print(df_tabula[1].head())

# no matter which of the 4 DFs we take, we need to fix the first row, whose data also belongs to the columns
print(df_tabula[0].columns)
# Out:
#       Rechnung        Budget Nachtragskredit  Konto
# 0         2021          2022            2022    NaN  \
# 1  667 662 996   676 632 100      69 858 232    NaN
# 2  669 234 686  -654 888 370             NaN    NaN
# 3   -1 571 690    21 743 730      69 858 232    NaN
# 4  264 728 060   273 568 210       1 929 450   30.0
#
#                                       Unnamed: 0   Rechnung 2022  Unnamed: 1
# 0                                            NaN   AufwandErtrag         NaN  \
# 1                                        Aufwand  806 710 659.40         NaN
# 2                                         Ertrag  802 024 241.24         NaN
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)    4 686 418.16         NaN
# 4                                Personalaufwand  261 488 439.52         NaN
#
#          Abweichung
# 0  RG / BU inkl. NK
# 1        60 220 327
# 2      -147 135 871
# 3       166 146 612
# 4       -14 009 220
#     Rechnung     Budget Nachtragskredit  Konto
# 0       2021       2022            2022    NaN  \
# 1        NaN        NaN             NaN  349.0
# 2  6 802 685  8 825 770             NaN   35.0
# 3    885 414    389 500             NaN  350.0
# 4  5 917 271  8 436 270             NaN  351.0
#
#                                           Unnamed: 0  Rechnung 2022
# 0                                                NaN  AufwandErtrag  \
# 1                              Übriger Finanzaufwand         711.45
# 2        Einlagen in Fonds und Spezialfinanzierungen  11 165 529.14
# 3  Einlagen in Fonds und Spezialfinanzierungen im...   1 732 517.82
# 4  Einlagen in Fonds und Spezialfinanzierungen de...   9 433 011.32
#
#    Unnamed: 1        Abweichung
# 0         NaN  RG / BU inkl. NK
# 1         NaN               711
# 2         NaN         2 339 759
# 3         NaN         1 343 018
# 4         NaN           996 741
# Index(['Rechnung', 'Budget', 'Nachtragskredit', 'Konto', 'Unnamed: 0',
#        'Rechnung 2022', 'Unnamed: 1', 'Abweichung'],
#       dtype='object')

# %% [markdown]
# #### This code takes the column names, adds the part that got saved as first row and removes the first row. We also remove the one empty column and rename another 2 columns

# %%
first_df = df_tabula[0].copy() # copying the df of the first page to apply manipulation to it

# saving old column names
old_col_names = first_df.columns.to_list()


# list with new column names
new_col_names = []
for name in old_col_names:
    first_line = " " + str(first_df.loc[0, name])
    if "nan" in first_line: # not copying nan values
        first_line = ""
    elif "AufwandErtrag" in first_line: # renaming "AufwandErtrag" with "Aufwand / Ertrag"
        first_line = " Aufwand / Ertrag"
    new_col_names.append(name + first_line)


# overwriting the column names
first_df.columns = new_col_names 


first_df = first_df.iloc[1:, :]  # eliminating the first row
first_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True) # renaming column "Unnamed: 0" -> "Beschreibung"  
first_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"

# %%
first_df.head()
# Out:
#   Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 1   667 662 996   676 632 100           69 858 232    NaN  \
# 2   669 234 686  -654 888 370                  NaN    NaN
# 3    -1 571 690    21 743 730           69 858 232    NaN
# 4   264 728 060   273 568 210            1 929 450   30.0
# 5     2 709 454     1 867 310                  NaN  300.0
#
#                                     Beschreibung
# 1                                        Aufwand  \
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
# 5                      Behörden und Kommissionen
#
#   Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 1                 806 710 659.40                  60 220 327
# 2                 802 024 241.24                -147 135 871
# 3                   4 686 418.16                 166 146 612
# 4                 261 488 439.52                 -14 009 220
# 5                   1 732 456.22                    -134 854

# %% [markdown]
# #### Making the dataframe cleaning for all the dataframes extracted (one per page of the PDF document)

# %%
cleaned_dfs = []

for single_df in df_tabula:

    print(single_df.head())

    old_col_names = single_df.columns.to_list()
    new_col_names = []
    for name in old_col_names:
        first_line = " " + str(single_df.loc[0, name])
        if "nan" in first_line: # not copying nan values
            first_line = ""
        elif "AufwandErtrag" in first_line: # renaming "AufwandErtrag" with "Aufwand / Ertrag"
            first_line = " Aufwand / Ertrag"
        new_col_names.append(name + first_line)
    single_df.columns = new_col_names 
    single_df = single_df.iloc[1:, :]  # eliminating the first row
    single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)

    print(single_df.head())

    single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"

    print(single_df.head())


    cleaned_dfs.append(single_df)
# Out:
#       Rechnung        Budget Nachtragskredit  Konto
# 0         2021          2022            2022    NaN  \
# 1  667 662 996   676 632 100      69 858 232    NaN
# 2  669 234 686  -654 888 370             NaN    NaN
# 3   -1 571 690    21 743 730      69 858 232    NaN
# 4  264 728 060   273 568 210       1 929 450   30.0
#
#                                       Unnamed: 0   Rechnung 2022  Unnamed: 1
# 0                                            NaN   AufwandErtrag         NaN  \
# 1                                        Aufwand  806 710 659.40         NaN
# 2                                         Ertrag  802 024 241.24         NaN
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)    4 686 418.16         NaN
# 4                                Personalaufwand  261 488 439.52         NaN
#
#          Abweichung
# 0  RG / BU inkl. NK
# 1        60 220 327
# 2      -147 135 871
# 3       166 146 612
# 4       -14 009 220
#   Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 1   667 662 996   676 632 100           69 858 232    NaN  \
# 2   669 234 686  -654 888 370                  NaN    NaN
# 3    -1 571 690    21 743 730           69 858 232    NaN
# 4   264 728 060   273 568 210            1 929 450   30.0
# 5     2 709 454     1 867 310                  NaN  300.0
#
#                                     Beschreibung
# 1                                        Aufwand  \
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
# 5                      Behörden und Kommissionen
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 1                 806 710 659.40         NaN                  60 220 327
# 2                 802 024 241.24         NaN                -147 135 871
# 3                   4 686 418.16         NaN                 166 146 612
# 4                 261 488 439.52         NaN                 -14 009 220
# 5                   1 732 456.22         NaN                    -134 854
#   Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 1   667 662 996   676 632 100           69 858 232    NaN  \
# 2   669 234 686  -654 888 370                  NaN    NaN
# 3    -1 571 690    21 743 730           69 858 232    NaN
# 4   264 728 060   273 568 210            1 929 450   30.0
# 5     2 709 454     1 867 310                  NaN  300.0
#
#                                     Beschreibung
# 1                                        Aufwand  \
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
# 5                      Behörden und Kommissionen
#
#   Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 1                 806 710 659.40                  60 220 327
# 2                 802 024 241.24                -147 135 871
# 3                   4 686 418.16                 166 146 612
# 4                 261 488 439.52                 -14 009 220
# 5                   1 732 456.22                    -134 854
#     Rechnung     Budget Nachtragskredit  Konto
# 0       2021       2022            2022    NaN  \
# 1        NaN        NaN             NaN  349.0
# 2  6 802 685  8 825 770             NaN   35.0
# 3    885 414    389 500             NaN  350.0
# 4  5 917 271  8 436 270             NaN  351.0
#
#                                           Unnamed: 0  Rechnung 2022
# 0                                                NaN  AufwandErtrag  \
# 1                              Übriger Finanzaufwand         711.45
# 2        Einlagen in Fonds und Spezialfinanzierungen  11 165 529.14
# 3  Einlagen in Fonds und Spezialfinanzierungen im...   1 732 517.82
# 4  Einlagen in Fonds und Spezialfinanzierungen de...   9 433 011.32
#
#    Unnamed: 1        Abweichung
# 0         NaN  RG / BU inkl. NK
# 1         NaN               711
# 2         NaN         2 339 759
# 3         NaN         1 343 018
# 4         NaN           996 741
#   Rechnung 2021  Budget 2022 Nachtragskredit 2022  Konto
# 1           NaN          NaN                  NaN  349.0  \
# 2     6 802 685    8 825 770                  NaN   35.0
# 3       885 414      389 500                  NaN  350.0
# 4     5 917 271    8 436 270                  NaN  351.0
# 5   182 707 206  191 728 880           12 569 957   36.0
#
#                                         Beschreibung
# 1                              Übriger Finanzaufwand  \
# 2        Einlagen in Fonds und Spezialfinanzierungen
# 3  Einlagen in Fonds und Spezialfinanzierungen im...
# 4  Einlagen in Fonds und Spezialfinanzierungen de...
# 5                                    Transferaufwand
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 1                         711.45         NaN                         711
# 2                  11 165 529.14         NaN                   2 339 759
# 3                   1 732 517.82         NaN                   1 343 018
# 4                   9 433 011.32         NaN                     996 741
# 5                 189 353 402.75         NaN                 -14 945 434
#   Rechnung 2021  Budget 2022 Nachtragskredit 2022  Konto
# 1           NaN          NaN                  NaN  349.0  \
# 2     6 802 685    8 825 770                  NaN   35.0
# 3       885 414      389 500                  NaN  350.0
# 4     5 917 271    8 436 270                  NaN  351.0
# 5   182 707 206  191 728 880           12 569 957   36.0
#
#                                         Beschreibung
# 1                              Übriger Finanzaufwand  \
# 2        Einlagen in Fonds und Spezialfinanzierungen
# 3  Einlagen in Fonds und Spezialfinanzierungen im...
# 4  Einlagen in Fonds und Spezialfinanzierungen de...
# 5                                    Transferaufwand
#
#   Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 1                         711.45                         711
# 2                  11 165 529.14                   2 339 759
# 3                   1 732 517.82                   1 343 018
# 4                   9 433 011.32                     996 741
# 5                 189 353 402.75                 -14 945 434
#        Rechnung        Budget  Nachtragskredit  Konto
# 0          2021          2022           2022.0    NaN  \
# 1      -668 253    -2 078 330              NaN   41.0
# 2      -668 253    -2 078 330              NaN  412.0
# 3  -129 585 164  -134 426 930              NaN   42.0
# 4    -6 136 934    -6 200 000              NaN  420.0
#
#                   Unnamed: 0   Rechnung 2022  Unnamed: 1        Abweichung
# 0                        NaN   AufwandErtrag         NaN  RG / BU inkl. NK
# 1  Regalien und Konzessionen    1 712 247.02         NaN           366 083
# 2               Konzessionen    1 712 247.02         NaN           366 083
# 3                   Entgelte  137 116 673.29         NaN        -2 689 743
# 4              Ersatzabgaben    6 386 952.11         NaN          -186 952
#   Rechnung 2021   Budget 2022  Nachtragskredit 2022.0  Konto
# 1      -668 253    -2 078 330                     NaN   41.0  \
# 2      -668 253    -2 078 330                     NaN  412.0
# 3  -129 585 164  -134 426 930                     NaN   42.0
# 4    -6 136 934    -6 200 000                     NaN  420.0
# 5   -16 404 009   -16 495 220                     NaN  421.0
#
#                   Beschreibung Rechnung 2022 Aufwand / Ertrag  Unnamed: 1
# 1    Regalien und Konzessionen                   1 712 247.02         NaN  \
# 2                 Konzessionen                   1 712 247.02         NaN
# 3                     Entgelte                 137 116 673.29         NaN
# 4                Ersatzabgaben                   6 386 952.11         NaN
# 5  Gebühren für Amtshandlungen                  14 741 388.27         NaN
#
#   Abweichung RG / BU inkl. NK
# 1                     366 083
# 2                     366 083
# 3                  -2 689 743
# 4                    -186 952
# 5                   1 753 832
#   Rechnung 2021   Budget 2022  Nachtragskredit 2022.0  Konto
# 1      -668 253    -2 078 330                     NaN   41.0  \
# 2      -668 253    -2 078 330                     NaN  412.0
# 3  -129 585 164  -134 426 930                     NaN   42.0
# 4    -6 136 934    -6 200 000                     NaN  420.0
# 5   -16 404 009   -16 495 220                     NaN  421.0
#
#                   Beschreibung Rechnung 2022 Aufwand / Ertrag
# 1    Regalien und Konzessionen                   1 712 247.02  \
# 2                 Konzessionen                   1 712 247.02
# 3                     Entgelte                 137 116 673.29
# 4                Ersatzabgaben                   6 386 952.11
# 5  Gebühren für Amtshandlungen                  14 741 388.27
#
#   Abweichung RG / BU inkl. NK
# 1                     366 083
# 2                     366 083
# 3                  -2 689 743
# 4                    -186 952
# 5                   1 753 832
#       Rechnung       Budget  Nachtragskredit  Konto
# 0         2021         2022           2022.0    NaN  \
# 1  -73 069 435  -67 912 540              NaN   46.0
# 2          NaN          NaN              NaN  460.0
# 3  -16 617 224  -17 147 430              NaN  461.0
# 4  -34 032 500  -32 800 600              NaN  462.0
#
#                                      Unnamed: 0  Rechnung 2022  Unnamed: 1
# 0                                           NaN  AufwandErtrag         NaN  \
# 1                                Transferertrag  74 330 728.70         NaN
# 2                    Ertragsanteile von Dritten       8 252.85         NaN
# 3  Entschädigungen von öffentlichen Gemeinwesen  18 128 905.33         NaN
# 4                   Finanz- und Lastenausgleich  32 841 900.00         NaN
#
#          Abweichung
# 0  RG / BU inkl. NK
# 1        -6 418 189
# 2            -8 253
# 3          -981 475
# 4           -41 300
#   Rechnung 2021  Budget 2022  Nachtragskredit 2022.0  Konto
# 1   -73 069 435  -67 912 540                     NaN   46.0  \
# 2           NaN          NaN                     NaN  460.0
# 3   -16 617 224  -17 147 430                     NaN  461.0
# 4   -34 032 500  -32 800 600                     NaN  462.0
# 5   -22 350 132  -17 841 610                     NaN  463.0
#
#                                         Beschreibung
# 1                                     Transferertrag  \
# 2                         Ertragsanteile von Dritten
# 3       Entschädigungen von öffentlichen Gemeinwesen
# 4                        Finanz- und Lastenausgleich
# 5  Beiträge von öffentlichen Gemeinwesen und Dritten
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 1                  74 330 728.70         NaN                  -6 418 189
# 2                       8 252.85         NaN                      -8 253
# 3                  18 128 905.33         NaN                    -981 475
# 4                  32 841 900.00         NaN                     -41 300
# 5                  23 150 518.67         NaN                  -5 308 909
#   Rechnung 2021  Budget 2022  Nachtragskredit 2022.0  Konto
# 1   -73 069 435  -67 912 540                     NaN   46.0  \
# 2           NaN          NaN                     NaN  460.0
# 3   -16 617 224  -17 147 430                     NaN  461.0
# 4   -34 032 500  -32 800 600                     NaN  462.0
# 5   -22 350 132  -17 841 610                     NaN  463.0
#
#                                         Beschreibung
# 1                                     Transferertrag  \
# 2                         Ertragsanteile von Dritten
# 3       Entschädigungen von öffentlichen Gemeinwesen
# 4                        Finanz- und Lastenausgleich
# 5  Beiträge von öffentlichen Gemeinwesen und Dritten
#
#   Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 1                  74 330 728.70                  -6 418 189
# 2                       8 252.85                      -8 253
# 3                  18 128 905.33                    -981 475
# 4                  32 841 900.00                     -41 300
# 5                  23 150 518.67                  -5 308 909
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)
# C:\Users\Alex Marchese\AppData\Local\Temp\ipykernel_10552\2281357688.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"

# %%
cleaned_dfs
# Out:
# [   Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
#  1    667 662 996   676 632 100           69 858 232    NaN  \
#  2    669 234 686  -654 888 370                  NaN    NaN
#  3     -1 571 690    21 743 730           69 858 232    NaN
#  4    264 728 060   273 568 210            1 929 450   30.0
#  5      2 709 454     1 867 310                  NaN  300.0
#  6    144 538 179   143 738 970            1 666 500  301.0
#  7     68 680 690    67 865 300                  NaN  302.0
#  8            NaN       889 730              103 920  303.0
#  9        844 506     8 801 740               19 000  304.0
#  10    39 799 252    40 945 200               55 300  305.0
#  11     5 245 198     5 956 230                  NaN  306.0
#  12     2 910 781     3 503 730               84 730  309.0
#  13    82 390 279    91 265 930            8 274 285   31.0
#  14    10 462 247    12 651 940              843 250  310.0
#  15     5 369 902     7 331 850              688 045  311.0
#  16     5 221 948     5 659 470            1 792 900  312.0
#  17    21 750 502    23 953 050            2 295 600  313.0
#  18    18 835 743    19 232 180              450 080  314.0
#  19     8 099 794     8 954 190              447 250  315.0
#  20     5 554 585     5 593 980            1 414 170  316.0
#  21     1 690 208     3 061 680              303 130  317.0
#  22     4 077 818     3 359 010               10 400  318.0
#  23     1 327 532     1 468 580               27 360  319.0
#  24    41 298 400    25 731 310           31 912 090   33.0
#  25    39 298 400    24 259 900           29 111 790  330.0
#  26     2 000 000     1 471 410            2 800 300  332.0
#  27    16 308 919    14 481 510           15 172 450   34.0
#  28     9 895 638    10 365 010                  NaN  340.0
#  29     3 028 348        10 000               19 100  341.0
#  30        47 038        64 000                  NaN  342.0
#  31     3 337 895     4 042 500              673 300  343.0
#  32           NaN           NaN           14 480 050  344.0
#
#                                           Beschreibung
#  1                                             Aufwand  \
#  2                                              Ertrag
#  3       Aufwandüberschuss (+) / Ertragsüberschuss (-)
#  4                                     Personalaufwand
#  5                           Behörden und Kommissionen
#  6        Löhne des Verwaltungs- und Betriebspersonals
#  7                              Löhne der Lehrpersonen
#  8                             Temporäre Arbeitskräfte
#  9                                             Zulagen
#  10                                Arbeitgeberbeiträge
#  11                              Arbeitgeberleistungen
#  12                            Übriger Personalaufwand
#  13                  Sach- und übriger Betriebsaufwand
#  14                         Material- und Warenaufwand
#  15                         Nicht aktivierbare Anlagen
#  16              Ver- und Entsorgung Liegenschaften VV
#  17                      Dienstleistungen und Honorare
#  18              Baulicher und betrieblicher Unterhalt
#  19        Unterhalt Mobilien und immaterielle Anlagen
#  20  Mieten, Leasing, Pachten, Benützungskostengebü...
#  21                              Spesenentschädigungen
#  22                 Wertberichtigungen auf Forderungen
#  23                            Übriger Betriebsaufwand
#  24                 Abschreibungen Verwaltungsvermögen
#  25                      Abschreibungen Sachanlagen VV
#  26                Abschreibungen immaterielle Anlagen
#  27                                      Finanzaufwand
#  28                                        Zinsaufwand
#  29                        Realisierte Kursverluste FV
#  30         Kapitalbeschaffungs- und Verwaltungskosten
#  31               Liegenschaftenaufwand Finanzvermögen
#  32                      Wertberichtigungen Anlagen FV
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
#  1                  806 710 659.40                  60 220 327
#  2                  802 024 241.24                -147 135 871
#  3                    4 686 418.16                 166 146 612
#  4                  261 488 439.52                 -14 009 220
#  5                    1 732 456.22                    -134 854
#  6                  140 219 925.58                  -5 185 544
#  7                   66 722 589.59                  -1 142 710
#  8                      352 033.05                    -641 617
#  9                    8 878 288.55                      57 549
#  10                  39 781 095.05                  -1 219 405
#  11                     574 783.16                  -5 381 447
#  12                   3 227 268.32                    -361 192
#  13                  87 567 262.20                 -11 972 953
#  14                  12 221 751.97                  -1 273 438
#  15                   5 914 294.56                  -2 105 600
#  16                   7 344 214.39                    -108 156
#  17                  22 509 359.19                  -3 739 291
#  18                  18 231 450.01                  -1 450 810
#  19                   8 478 678.52                    -922 761
#  20                   5 956 780.26                  -1 051 370
#  21                   2 769 027.69                    -595 782
#  22                   3 269 744.30                     -99 666
#  23                     871 961.31                    -623 979
#  24                  45 650 209.83                 -11 993 190
#  25                  41 893 202.36                 -11 478 488
#  26                   3 757 007.47                    -514 703
#  27                  34 256 710.56                   4 602 751
#  28                   9 573 732.06                    -791 278
#  29                      20 624.60                      -8 475
#  30                      59 006.29                      -4 994
#  31                   4 721 786.16                       5 986
#  32                  19 880 850.00                   5 400 800  ,
#     Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
#  1            NaN           NaN                  NaN  349.0  \
#  2      6 802 685     8 825 770                  NaN   35.0
#  3        885 414       389 500                  NaN  350.0
#  4      5 917 271     8 436 270                  NaN  351.0
#  5    182 707 206   191 728 880           12 569 957   36.0
#  6      1 551 447     1 399 850               34 900  360.0
#  7     22 439 842    24 323 800            1 163 200  361.0
#  8    155 812 862   164 827 230           11 368 357  363.0
#  9          1 000           NaN                  NaN  364.0
#  10     2 902 055     1 038 000                  NaN  366.0
#  11           NaN       140 000                3 500  369.0
#  12           NaN       929 160                  NaN   38.0
#  13           NaN       929 160                  NaN  389.0
#  14    73 427 447    70 101 330                  NaN   39.0
#  15        85 082         7 500                  NaN  390.0
#  16    29 808 829    19 537 460                  NaN  391.0
#  17     4 701 304     4 058 500                  NaN  392.0
#  18     4 952 721    11 999 310                  NaN  393.0
#  19    12 481 113    10 440 050                  NaN  394.0
#  20     4 419 192    24 058 510                  NaN  398.0
#  21    16 979 206           NaN                  NaN  399.0
#  22  -332 271 474  -330 380 000                  NaN   40.0
#  23  -255 195 121  -256 100 000                  NaN  400.0
#  24   -35 829 998   -34 600 000                  NaN  401.0
#  25   -40 937 115   -39 400 000                  NaN  402.0
#  26      -309 240      -280 000                  NaN  403.0
#
#                                           Beschreibung
#  1                               Übriger Finanzaufwand  \
#  2         Einlagen in Fonds und Spezialfinanzierungen
#  3   Einlagen in Fonds und Spezialfinanzierungen im...
#  4   Einlagen in Fonds und Spezialfinanzierungen de...
#  5                                     Transferaufwand
#  6                            Ertragsanteile an Dritte
#  7          Entschädigungen an öffentliche Gemeinwesen
#  8      Beiträge an öffentliche Gemeinwesen und Dritte
#  9                      Wertberichtigungen Darlehen VV
#  10                Abschreibungen Investitionsbeiträge
#  11                            Übriger Transferaufwand
#  12                               Einlagen in Reserven
#  13                       Einlagen in das Eigenkapital
#  14                              Interne Verrechnungen
#  15                          Material- und Warenbezüge
#  16                                   Dienstleistungen
#  17                    Pacht, Mieten, Benützungskosten
#  18                    Betriebs- und Verwaltungskosten
#  19                     Kalk. Zinsen und Finanzaufwand
#  20                                      Übertragungen
#  21                       Übrige interne Verrechnungen
#  22                                       Fiskalertrag
#  23                Direkte Steuern natürliche Personen
#  24               Direkte Steuern juristische Personen
#  25                             Übrige direkte Steuern
#  26                         Besitz- und Aufwandsteuern
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
#  1                          711.45                         711
#  2                   11 165 529.14                   2 339 759
#  3                    1 732 517.82                   1 343 018
#  4                    9 433 011.32                     996 741
#  5                  189 353 402.75                 -14 945 434
#  6                    1 434 769.33                          19
#  7                   25 506 339.85                      19 340
#  8                  162 346 402.67                 -13 849 184
#  9                             NaN                         NaN
#  10                            NaN                  -1 038 000
#  11                      65 890.90                     -77 609
#  12                  46 199 646.53                  45 270 487
#  13                  46 199 646.53                 -45 270 487
#  14                 131 029 458.87                  60 928 129
#  15                       5 564.40                      -1 936
#  16                  18 423 662.42                  -1 113 798
#  17                   8 026 914.59                   3 968 415
#  18                  11 204 631.22                    -794 679
#  19                  16 103 401.06                   5 663 351
#  20                  25 622 335.33                   1 563 825
#  21                  51 642 949.85                  51 642 950
#  22                 364 159 104.08                 -33 779 104
#  23                 266 374 712.34                 -10 274 712
#  24                  50 960 503.50                 -16 360 504
#  25                  46 501 138.24                  -7 101 138
#  26                     322 750.00                     -42 750  ,
#     Rechnung 2021   Budget 2022  Nachtragskredit 2022.0  Konto
#  1       -668 253    -2 078 330                     NaN   41.0  \
#  2       -668 253    -2 078 330                     NaN  412.0
#  3   -129 585 164  -134 426 930                     NaN   42.0
#  4     -6 136 934    -6 200 000                     NaN  420.0
#  5    -16 404 009   -16 495 220                     NaN  421.0
#  6     -2 163 746    -2 413 560                     NaN  422.0
#  7     -1 546 769    -1 537 200                     NaN  423.0
#  8    -49 365 462   -54 988 990                     NaN  424.0
#  9     -5 809 102    -4 493 210                     NaN  425.0
#  10   -39 225 549   -39 217 940                     NaN  426.0
#  11    -4 639 093    -5 546 710                     NaN  427.0
#  12    -4 294 500    -3 534 100                     NaN  429.0
#  13    -2 700 289    -2 768 010                     NaN   43.0
#  14       -90 897      -204 050                     NaN  430.0
#  15    -2 593 241    -2 547 160                     NaN  431.0
#  16       -16 151       -16 800                     NaN  439.0
#  17   -42 277 515   -36 326 770                     NaN   44.0
#  18    -1 173 114      -717 410                     NaN  440.0
#  19    -3 738 673    -3 008 000                     NaN  441.0
#  20      -117 513      -319 790                     NaN  442.0
#  21   -16 593 569   -16 046 980                     NaN  443.0
#  22           NaN           NaN                     NaN  444.0
#  23    -7 774 102    -7 201 290                     NaN  445.0
#  24    -8 000 000    -4 000 000                     NaN  446.0
#  25    -4 758 527    -4 907 420                     NaN  447.0
#  26      -122 017      -125 880                     NaN  448.0
#  27           NaN           NaN                     NaN  449.0
#  28    -4 173 081      -163 250                     NaN   45.0
#  29           NaN           NaN                     NaN  450.0
#  30    -4 173 081      -163 250                     NaN  451.0
#
#                                           Beschreibung
#  1                           Regalien und Konzessionen  \
#  2                                        Konzessionen
#  3                                            Entgelte
#  4                                       Ersatzabgaben
#  5                         Gebühren für Amtshandlungen
#  6                   Spital- und Heimtaxen, Kostgelder
#  7                               Schul- und Kursgelder
#  8             Benützungsgebühren und Dienstleistungen
#  9                                 Erlös aus Verkäufen
#  10                                   Rückerstattungen
#  11                                             Bussen
#  12                                    Übrige Entgelte
#  13                               Verschiedene Erträge
#  14                        Übrige betriebliche Erträge
#  15                        Aktivierung Eigenleistungen
#  16                                     Übriger Ertrag
#  17                                       Finanzertrag
#  18                                         Zinsertrag
#  19                             Realisierte Gewinne FV
#  20                              Beteiligungsertrag FV
#  21                            Liegenschaftenertrag FV
#  22                      Wertberichtigungen Anlagen FV
#  23  Finanzertrag aus Darlehen und Beteiligungen de...
#  24       Finanzertrag von öffentlichen Unternehmungen
#  25                            Liegenschaftenertrag VV
#  26              Erträge von gemieteten Liegenschaften
#  27                               Übrige Finanzerträge
#  28  Entnahmen aus Fonds und Spezialfinanzierungen ...
#  29  Entnahmen aus Fonds und Spezialfinanzierungen ...
#  30  Entnahmen aus Fonds und Spezialfinanzierungen ...
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
#  1                    1 712 247.02                     366 083
#  2                    1 712 247.02                     366 083
#  3                  137 116 673.29                  -2 689 743
#  4                    6 386 952.11                    -186 952
#  5                   14 741 388.27                   1 753 832
#  6                      503 326.60                   1 910 233
#  7                    1 572 781.89                     -35 582
#  8                   58 193 906.20                  -3 204 916
#  9                    5 770 399.12                  -1 277 189
#  10                  40 631 321.70                  -1 413 382
#  11                   5 373 343.11                     173 367
#  12                   3 943 254.29                    -409 154
#  13                   2 494 437.12                     273 573
#  14                     113 681.74                      90 368
#  15                   2 341 269.39                     205 891
#  16                      39 485.99                     -22 686
#  17                  80 295 182.51                 -43 968 413
#  18                     708 273.08                       9 137
#  19                   1 308 989.76                   1 699 010
#  20                     507 780.00                    -187 990
#  21                  20 476 293.80                  -4 429 314
#  22                  45 108 280.00                 -45 108 280
#  23                   6 770 608.70                     430 681
#  24                   4 000 000.00                         NaN
#  25                   1 252 216.33                   3 655 204
#  26                     162 778.20                     -36 898
#  27                         -37.36                          37
#  28                     155 199.65                       8 050
#  29                      22 259.50                     -22 260
#  30                     132 940.15                      30 310  ,
#     Rechnung 2021  Budget 2022  Nachtragskredit 2022.0  Konto
#  1    -73 069 435  -67 912 540                     NaN   46.0  \
#  2            NaN          NaN                     NaN  460.0
#  3    -16 617 224  -17 147 430                     NaN  461.0
#  4    -34 032 500  -32 800 600                     NaN  462.0
#  5    -22 350 132  -17 841 610                     NaN  463.0
#  6        -69 579     -122 900                     NaN  469.0
#  7    -11 319 545  -10 731 210                     NaN   48.0
#  8    -11 319 545  -10 731 210                     NaN  489.0
#  9    -73 169 930  -70 101 330                     NaN   49.0
#  10      -312 704       -7 500                     NaN  490.0
#  11   -18 407 658  -19 537 460                     NaN  491.0
#  12    -4 166 715   -4 058 500                     NaN  492.0
#  13   -10 850 201  -11 999 310                     NaN  493.0
#  14   -12 481 111  -10 440 050                     NaN  494.0
#  15    -9 855 945  -24 058 510                     NaN  498.0
#  16   -17 095 596          NaN                     NaN  499.0
#
#                                           Beschreibung
#  1                                      Transferertrag  \
#  2                          Ertragsanteile von Dritten
#  3        Entschädigungen von öffentlichen Gemeinwesen
#  4                         Finanz- und Lastenausgleich
#  5   Beiträge von öffentlichen Gemeinwesen und Dritten
#  6                              Übriger Transferertrag
#  7                              Entnahmen aus Reserven
#  8                      Entnahmen aus dem Eigenkapital
#  9                               Interne Verrechnungen
#  10                          Material- und Warenbezüge
#  11                                   Dienstleistungen
#  12                    Pacht, Mieten, Benützungskosten
#  13                    Betriebs- und Verwaltungskosten
#  14                     Kalk. Zinsen und Finanzaufwand
#  15                                      Übertragungen
#  16                       Übrige interne Verrechnungen
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
#  1                   74 330 728.70                  -6 418 189
#  2                        8 252.85                      -8 253
#  3                   18 128 905.33                    -981 475
#  4                   32 841 900.00                     -41 300
#  5                   23 150 518.67                  -5 308 909
#  6                      201 151.85                     -78 252
#  7                   10 731 210.00                         NaN
#  8                   10 731 210.00                         NaN
#  9                  131 029 458.87                 -60 928 129
#  10                       5 564.40                       1 936
#  11                  18 423 662.42                   1 113 798
#  12                   8 026 914.59                  -3 968 415
#  13                  11 204 631.22                     794 679
#  14                  16 103 401.06                  -5 663 351
#  15                  25 622 335.33                  -1 563 825
#  16                  51 642 949.85                 -51 642 950  ]

# %% [markdown]
# #### combining all dataframes (one per page extracted) into a single df

# %%
# I am cominbing all dataframes (one per page extracted) into a single df

df = pd.concat(cleaned_dfs)

# %%
# veryfying that the output is correct

print(df)
print(df.info()) # as we can see, during the process the column "Nachtragskredit 2022.0" got added. 
                 # This could be do to tabula creating it by mistake during the reading process

                 # Also, the row numbers repeat themselves, so we have to reset the row indexes
# Out:
#    Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 1    667 662 996   676 632 100           69 858 232    NaN  \
# 2    669 234 686  -654 888 370                  NaN    NaN
# 3     -1 571 690    21 743 730           69 858 232    NaN
# 4    264 728 060   273 568 210            1 929 450   30.0
# 5      2 709 454     1 867 310                  NaN  300.0
# ..           ...           ...                  ...    ...
# 12    -4 166 715    -4 058 500                  NaN  492.0
# 13   -10 850 201   -11 999 310                  NaN  493.0
# 14   -12 481 111   -10 440 050                  NaN  494.0
# 15    -9 855 945   -24 058 510                  NaN  498.0
# 16   -17 095 596           NaN                  NaN  499.0
#
#                                      Beschreibung
# 1                                         Aufwand  \
# 2                                          Ertrag
# 3   Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                 Personalaufwand
# 5                       Behörden und Kommissionen
# ..                                            ...
# 12                Pacht, Mieten, Benützungskosten
# 13                Betriebs- und Verwaltungskosten
# 14                 Kalk. Zinsen und Finanzaufwand
# 15                                  Übertragungen
# 16                   Übrige interne Verrechnungen
#
#    Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 1                  806 710 659.40                  60 220 327  \
# 2                  802 024 241.24                -147 135 871
# 3                    4 686 418.16                 166 146 612
# 4                  261 488 439.52                 -14 009 220
# 5                    1 732 456.22                    -134 854
# ..                            ...                         ...
# 12                   8 026 914.59                  -3 968 415
# 13                  11 204 631.22                     794 679
# 14                  16 103 401.06                  -5 663 351
# 15                  25 622 335.33                  -1 563 825
# 16                  51 642 949.85                 -51 642 950
#
#     Nachtragskredit 2022.0
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# ..                     ...
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
#
# [104 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 1 to 16
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rechnung 2021                   94 non-null     object
#  1   Budget 2022                     95 non-null     object
#  2   Nachtragskredit 2022            31 non-null     object
#  3   Konto                           101 non-null    float64
#  4   Beschreibung                    104 non-null    object
#  5   Rechnung 2022 Aufwand / Ertrag  102 non-null    object
#  6   Abweichung RG / BU inkl. NK     100 non-null    object
#  7   Nachtragskredit 2022.0          0 non-null      float64
# dtypes: float64(2), object(6)
# memory usage: 7.3+ KB
# None

# %%
df.drop(columns=['Nachtragskredit 2022.0'], inplace=True) # removing "Nachtragskredit 2022.0"
df.reset_index(inplace=True) # resetting indexes

# %%
# check

print(df)
print(df.info()) # we do not need the former index row either, so let's drop it
# Out:
#      index Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 0        1   667 662 996   676 632 100           69 858 232    NaN  \
# 1        2   669 234 686  -654 888 370                  NaN    NaN
# 2        3    -1 571 690    21 743 730           69 858 232    NaN
# 3        4   264 728 060   273 568 210            1 929 450   30.0
# 4        5     2 709 454     1 867 310                  NaN  300.0
# ..     ...           ...           ...                  ...    ...
# 99      12    -4 166 715    -4 058 500                  NaN  492.0
# 100     13   -10 850 201   -11 999 310                  NaN  493.0
# 101     14   -12 481 111   -10 440 050                  NaN  494.0
# 102     15    -9 855 945   -24 058 510                  NaN  498.0
# 103     16   -17 095 596           NaN                  NaN  499.0
#
#                                       Beschreibung
# 0                                          Aufwand  \
# 1                                           Ertrag
# 2    Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 3                                  Personalaufwand
# 4                        Behörden und Kommissionen
# ..                                             ...
# 99                 Pacht, Mieten, Benützungskosten
# 100                Betriebs- und Verwaltungskosten
# 101                 Kalk. Zinsen und Finanzaufwand
# 102                                  Übertragungen
# 103                   Übrige interne Verrechnungen
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 0                   806 710 659.40                  60 220 327
# 1                   802 024 241.24                -147 135 871
# 2                     4 686 418.16                 166 146 612
# 3                   261 488 439.52                 -14 009 220
# 4                     1 732 456.22                    -134 854
# ..                             ...                         ...
# 99                    8 026 914.59                  -3 968 415
# 100                  11 204 631.22                     794 679
# 101                  16 103 401.06                  -5 663 351
# 102                  25 622 335.33                  -1 563 825
# 103                  51 642 949.85                 -51 642 950
#
# [104 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           104 non-null    int64
#  1   Rechnung 2021                   94 non-null     object
#  2   Budget 2022                     95 non-null     object
#  3   Nachtragskredit 2022            31 non-null     object
#  4   Konto                           101 non-null    float64
#  5   Beschreibung                    104 non-null    object
#  6   Rechnung 2022 Aufwand / Ertrag  102 non-null    object
#  7   Abweichung RG / BU inkl. NK     100 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.6+ KB
# None

# %%
df.drop(columns=['index'], inplace=True) # removing "index" column

# %%
# check

print(df)
print(df.info()) # brilliant
# Out:
#     Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 0     667 662 996   676 632 100           69 858 232    NaN  \
# 1     669 234 686  -654 888 370                  NaN    NaN
# 2      -1 571 690    21 743 730           69 858 232    NaN
# 3     264 728 060   273 568 210            1 929 450   30.0
# 4       2 709 454     1 867 310                  NaN  300.0
# ..            ...           ...                  ...    ...
# 99     -4 166 715    -4 058 500                  NaN  492.0
# 100   -10 850 201   -11 999 310                  NaN  493.0
# 101   -12 481 111   -10 440 050                  NaN  494.0
# 102    -9 855 945   -24 058 510                  NaN  498.0
# 103   -17 095 596           NaN                  NaN  499.0
#
#                                       Beschreibung
# 0                                          Aufwand  \
# 1                                           Ertrag
# 2    Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 3                                  Personalaufwand
# 4                        Behörden und Kommissionen
# ..                                             ...
# 99                 Pacht, Mieten, Benützungskosten
# 100                Betriebs- und Verwaltungskosten
# 101                 Kalk. Zinsen und Finanzaufwand
# 102                                  Übertragungen
# 103                   Übrige interne Verrechnungen
#
#     Rechnung 2022 Aufwand / Ertrag Abweichung RG / BU inkl. NK
# 0                   806 710 659.40                  60 220 327
# 1                   802 024 241.24                -147 135 871
# 2                     4 686 418.16                 166 146 612
# 3                   261 488 439.52                 -14 009 220
# 4                     1 732 456.22                    -134 854
# ..                             ...                         ...
# 99                    8 026 914.59                  -3 968 415
# 100                  11 204 631.22                     794 679
# 101                  16 103 401.06                  -5 663 351
# 102                  25 622 335.33                  -1 563 825
# 103                  51 642 949.85                 -51 642 950
#
# [104 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rechnung 2021                   94 non-null     object
#  1   Budget 2022                     95 non-null     object
#  2   Nachtragskredit 2022            31 non-null     object
#  3   Konto                           101 non-null    float64
#  4   Beschreibung                    104 non-null    object
#  5   Rechnung 2022 Aufwand / Ertrag  102 non-null    object
#  6   Abweichung RG / BU inkl. NK     100 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 5.8+ KB
# None

# %% [markdown]
# #### Now that everything works, I am saving the merged df with financial information from the year 2022 from the City of St. Gallen as an Excel file and manually check that all revelvant information got read. That is the case

# %%
df.to_excel("Combined 2022 SG.xlsx")

# %% [markdown]
# ## 5. Fixing Pandas errors

# %% [markdown]
# #### When running the Pandas code created before to manipulate the single DF on multiple reports, we get an error. It says "['Unnamed: 1'] not found in axis". This is an undesired column that it apparently is not found.
#
# #### We also get pointed to a documentation link (https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy).
#
# #### This seems to be related to some warnings we got when creating the code before

# %%
# code we used
cleaned_dfs = []

for single_df in df_tabula:

    print(single_df.head())

    old_col_names = single_df.columns.to_list()
    new_col_names = []
    for name in old_col_names:
        first_line = " " + str(single_df.loc[0, name])
        if "nan" in first_line: # not copying nan values
            first_line = ""
        elif "AufwandErtrag" in first_line: # renaming "AufwandErtrag" with "Aufwand / Ertrag"
            first_line = " Aufwand / Ertrag"
        new_col_names.append(name + first_line)
    single_df.columns = new_col_names 
    single_df = single_df.iloc[1:, :]  # eliminating the first row
    # single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1, inplace=True)
    single_df = single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1)

    print(single_df.head())

    # single_df.drop(columns=['Unnamed: 1'], inplace=True) # removing "Unnamed: 1"
    single_df = single_df.drop(columns=['Unnamed: 1']) 

    print(single_df.head())


    cleaned_dfs.append(single_df)
# Out:
#   Rechnung 2021   Budget 2022 Nachtragskredit 2022  Konto
# 0          2021          2022                 2022    NaN  \
# 1   667 662 996   676 632 100           69 858 232    NaN
# 2   669 234 686  -654 888 370                  NaN    NaN
# 3    -1 571 690    21 743 730           69 858 232    NaN
# 4   264 728 060   273 568 210            1 929 450   30.0
#
#                                       Unnamed: 0
# 0                                            NaN  \
# 1                                        Aufwand
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 0                  AufwandErtrag         NaN            RG / BU inkl. NK
# 1                 806 710 659.40         NaN                  60 220 327
# 2                 802 024 241.24         NaN                -147 135 871
# 3                   4 686 418.16         NaN                 166 146 612
# 4                 261 488 439.52         NaN                 -14 009 220
#   Rechnung 2021 2021 Budget 2022 2022 Nachtragskredit 2022 2022  Konto
# 1        667 662 996      676 632 100                69 858 232    NaN  \
# 2        669 234 686     -654 888 370                       NaN    NaN
# 3         -1 571 690       21 743 730                69 858 232    NaN
# 4        264 728 060      273 568 210                 1 929 450   30.0
# 5          2 709 454        1 867 310                       NaN  300.0
#
#                                     Beschreibung
# 1                                        Aufwand  \
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
# 5                      Behörden und Kommissionen
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag  Unnamed: 1
# 1                                  806 710 659.40         NaN  \
# 2                                  802 024 241.24         NaN
# 3                                    4 686 418.16         NaN
# 4                                  261 488 439.52         NaN
# 5                                    1 732 456.22         NaN
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                   60 220 327
# 2                                 -147 135 871
# 3                                  166 146 612
# 4                                  -14 009 220
# 5                                     -134 854
#   Rechnung 2021 2021 Budget 2022 2022 Nachtragskredit 2022 2022  Konto
# 1        667 662 996      676 632 100                69 858 232    NaN  \
# 2        669 234 686     -654 888 370                       NaN    NaN
# 3         -1 571 690       21 743 730                69 858 232    NaN
# 4        264 728 060      273 568 210                 1 929 450   30.0
# 5          2 709 454        1 867 310                       NaN  300.0
#
#                                     Beschreibung
# 1                                        Aufwand  \
# 2                                         Ertrag
# 3  Aufwandüberschuss (+) / Ertragsüberschuss (-)
# 4                                Personalaufwand
# 5                      Behörden und Kommissionen
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag
# 1                                  806 710 659.40  \
# 2                                  802 024 241.24
# 3                                    4 686 418.16
# 4                                  261 488 439.52
# 5                                    1 732 456.22
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                   60 220 327
# 2                                 -147 135 871
# 3                                  166 146 612
# 4                                  -14 009 220
# 5                                     -134 854
#   Rechnung 2021 Budget 2022 Nachtragskredit 2022  Konto
# 0          2021        2022                 2022    NaN  \
# 1           NaN         NaN                  NaN  349.0
# 2     6 802 685   8 825 770                  NaN   35.0
# 3       885 414     389 500                  NaN  350.0
# 4     5 917 271   8 436 270                  NaN  351.0
#
#                                           Unnamed: 0
# 0                                                NaN  \
# 1                              Übriger Finanzaufwand
# 2        Einlagen in Fonds und Spezialfinanzierungen
# 3  Einlagen in Fonds und Spezialfinanzierungen im...
# 4  Einlagen in Fonds und Spezialfinanzierungen de...
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 0                  AufwandErtrag         NaN            RG / BU inkl. NK
# 1                         711.45         NaN                         711
# 2                  11 165 529.14         NaN                   2 339 759
# 3                   1 732 517.82         NaN                   1 343 018
# 4                   9 433 011.32         NaN                     996 741
#   Rechnung 2021 2021 Budget 2022 2022 Nachtragskredit 2022 2022  Konto
# 1                NaN              NaN                       NaN  349.0  \
# 2          6 802 685        8 825 770                       NaN   35.0
# 3            885 414          389 500                       NaN  350.0
# 4          5 917 271        8 436 270                       NaN  351.0
# 5        182 707 206      191 728 880                12 569 957   36.0
#
#                                         Beschreibung
# 1                              Übriger Finanzaufwand  \
# 2        Einlagen in Fonds und Spezialfinanzierungen
# 3  Einlagen in Fonds und Spezialfinanzierungen im...
# 4  Einlagen in Fonds und Spezialfinanzierungen de...
# 5                                    Transferaufwand
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag  Unnamed: 1
# 1                                          711.45         NaN  \
# 2                                   11 165 529.14         NaN
# 3                                    1 732 517.82         NaN
# 4                                    9 433 011.32         NaN
# 5                                  189 353 402.75         NaN
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                          711
# 2                                    2 339 759
# 3                                    1 343 018
# 4                                      996 741
# 5                                  -14 945 434
#   Rechnung 2021 2021 Budget 2022 2022 Nachtragskredit 2022 2022  Konto
# 1                NaN              NaN                       NaN  349.0  \
# 2          6 802 685        8 825 770                       NaN   35.0
# 3            885 414          389 500                       NaN  350.0
# 4          5 917 271        8 436 270                       NaN  351.0
# 5        182 707 206      191 728 880                12 569 957   36.0
#
#                                         Beschreibung
# 1                              Übriger Finanzaufwand  \
# 2        Einlagen in Fonds und Spezialfinanzierungen
# 3  Einlagen in Fonds und Spezialfinanzierungen im...
# 4  Einlagen in Fonds und Spezialfinanzierungen de...
# 5                                    Transferaufwand
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag
# 1                                          711.45  \
# 2                                   11 165 529.14
# 3                                    1 732 517.82
# 4                                    9 433 011.32
# 5                                  189 353 402.75
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                          711
# 2                                    2 339 759
# 3                                    1 343 018
# 4                                      996 741
# 5                                  -14 945 434
#   Rechnung 2021   Budget 2022  Nachtragskredit 2022.0  Konto
# 0          2021          2022                  2022.0    NaN  \
# 1      -668 253    -2 078 330                     NaN   41.0
# 2      -668 253    -2 078 330                     NaN  412.0
# 3  -129 585 164  -134 426 930                     NaN   42.0
# 4    -6 136 934    -6 200 000                     NaN  420.0
#
#                   Unnamed: 0 Rechnung 2022 Aufwand / Ertrag  Unnamed: 1
# 0                        NaN                  AufwandErtrag         NaN  \
# 1  Regalien und Konzessionen                   1 712 247.02         NaN
# 2               Konzessionen                   1 712 247.02         NaN
# 3                   Entgelte                 137 116 673.29         NaN
# 4              Ersatzabgaben                   6 386 952.11         NaN
#
#   Abweichung RG / BU inkl. NK
# 0            RG / BU inkl. NK
# 1                     366 083
# 2                     366 083
# 3                  -2 689 743
# 4                    -186 952
#   Rechnung 2021 2021 Budget 2022 2022  Nachtragskredit 2022.0 2022.0  Konto
# 1           -668 253       -2 078 330                            NaN   41.0  \
# 2           -668 253       -2 078 330                            NaN  412.0
# 3       -129 585 164     -134 426 930                            NaN   42.0
# 4         -6 136 934       -6 200 000                            NaN  420.0
# 5        -16 404 009      -16 495 220                            NaN  421.0
#
#                   Beschreibung
# 1    Regalien und Konzessionen  \
# 2                 Konzessionen
# 3                     Entgelte
# 4                Ersatzabgaben
# 5  Gebühren für Amtshandlungen
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag  Unnamed: 1
# 1                                    1 712 247.02         NaN  \
# 2                                    1 712 247.02         NaN
# 3                                  137 116 673.29         NaN
# 4                                    6 386 952.11         NaN
# 5                                   14 741 388.27         NaN
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                      366 083
# 2                                      366 083
# 3                                   -2 689 743
# 4                                     -186 952
# 5                                    1 753 832
#   Rechnung 2021 2021 Budget 2022 2022  Nachtragskredit 2022.0 2022.0  Konto
# 1           -668 253       -2 078 330                            NaN   41.0  \
# 2           -668 253       -2 078 330                            NaN  412.0
# 3       -129 585 164     -134 426 930                            NaN   42.0
# 4         -6 136 934       -6 200 000                            NaN  420.0
# 5        -16 404 009      -16 495 220                            NaN  421.0
#
#                   Beschreibung
# 1    Regalien und Konzessionen  \
# 2                 Konzessionen
# 3                     Entgelte
# 4                Ersatzabgaben
# 5  Gebühren für Amtshandlungen
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag
# 1                                    1 712 247.02  \
# 2                                    1 712 247.02
# 3                                  137 116 673.29
# 4                                    6 386 952.11
# 5                                   14 741 388.27
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                      366 083
# 2                                      366 083
# 3                                   -2 689 743
# 4                                     -186 952
# 5                                    1 753 832
#   Rechnung 2021  Budget 2022  Nachtragskredit 2022.0  Konto
# 0          2021         2022                  2022.0    NaN  \
# 1   -73 069 435  -67 912 540                     NaN   46.0
# 2           NaN          NaN                     NaN  460.0
# 3   -16 617 224  -17 147 430                     NaN  461.0
# 4   -34 032 500  -32 800 600                     NaN  462.0
#
#                                      Unnamed: 0
# 0                                           NaN  \
# 1                                Transferertrag
# 2                    Ertragsanteile von Dritten
# 3  Entschädigungen von öffentlichen Gemeinwesen
# 4                   Finanz- und Lastenausgleich
#
#   Rechnung 2022 Aufwand / Ertrag  Unnamed: 1 Abweichung RG / BU inkl. NK
# 0                  AufwandErtrag         NaN            RG / BU inkl. NK
# 1                  74 330 728.70         NaN                  -6 418 189
# 2                       8 252.85         NaN                      -8 253
# 3                  18 128 905.33         NaN                    -981 475
# 4                  32 841 900.00         NaN                     -41 300
#   Rechnung 2021 2021 Budget 2022 2022  Nachtragskredit 2022.0 2022.0  Konto
# 1        -73 069 435      -67 912 540                            NaN   46.0  \
# 2                NaN              NaN                            NaN  460.0
# 3        -16 617 224      -17 147 430                            NaN  461.0
# 4        -34 032 500      -32 800 600                            NaN  462.0
# 5        -22 350 132      -17 841 610                            NaN  463.0
#
#                                         Beschreibung
# 1                                     Transferertrag  \
# 2                         Ertragsanteile von Dritten
# 3       Entschädigungen von öffentlichen Gemeinwesen
# 4                        Finanz- und Lastenausgleich
# 5  Beiträge von öffentlichen Gemeinwesen und Dritten
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag  Unnamed: 1
# 1                                   74 330 728.70         NaN  \
# 2                                        8 252.85         NaN
# 3                                   18 128 905.33         NaN
# 4                                   32 841 900.00         NaN
# 5                                   23 150 518.67         NaN
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                   -6 418 189
# 2                                       -8 253
# 3                                     -981 475
# 4                                      -41 300
# 5                                   -5 308 909
#   Rechnung 2021 2021 Budget 2022 2022  Nachtragskredit 2022.0 2022.0  Konto
# 1        -73 069 435      -67 912 540                            NaN   46.0  \
# 2                NaN              NaN                            NaN  460.0
# 3        -16 617 224      -17 147 430                            NaN  461.0
# 4        -34 032 500      -32 800 600                            NaN  462.0
# 5        -22 350 132      -17 841 610                            NaN  463.0
#
#                                         Beschreibung
# 1                                     Transferertrag  \
# 2                         Ertragsanteile von Dritten
# 3       Entschädigungen von öffentlichen Gemeinwesen
# 4                        Finanz- und Lastenausgleich
# 5  Beiträge von öffentlichen Gemeinwesen und Dritten
#
#   Rechnung 2022 Aufwand / Ertrag Aufwand / Ertrag
# 1                                   74 330 728.70  \
# 2                                        8 252.85
# 3                                   18 128 905.33
# 4                                   32 841 900.00
# 5                                   23 150 518.67
#
#   Abweichung RG / BU inkl. NK RG / BU inkl. NK
# 1                                   -6 418 189
# 2                                       -8 253
# 3                                     -981 475
# 4                                      -41 300
# 5                                   -5 308 909

# %% [markdown]
# #### Browsing a bit around, we get recommended not to use the replace parameter (https://stackoverflow.com/questions/33727667/pandas-settingwithcopywarning-a-value-is-trying-to-be-set-on-a-copy-of-a-slice). This indeed helps getting rid of the warnings

# %% [markdown]
# #### The warnings have disappeared, but the error is still there in the main python script. That means, it was not related to the warnings

# %%
# rerunning the code with "report 2008", This is the first one processed an throwing an error

df_tabula_08 = read_pdf("cut reduced 2008 Rechnung.pdf", pages="all")


cleaned_dfs = []

for single_df in df_tabula_08:

    print(single_df.head())
    print(type(single_df.head()))

    old_col_names = single_df.columns.to_list()
    new_col_names = []
    for name in old_col_names:
        first_line = " " + str(single_df.loc[0, name])
        if "nan" in first_line: # not copying nan values
            first_line = ""
        elif "AufwandErtrag" in first_line: # renaming "AufwandErtrag" with "Aufwand / Ertrag"
            first_line = " Aufwand / Ertrag"
        new_col_names.append(name + first_line)
    single_df.columns = new_col_names 
    single_df = single_df.iloc[1:, :]  # eliminating the first row
    single_df = single_df.rename({'Unnamed: 0': 'Beschreibung'}, axis=1)

    print(single_df.head())

    # single_df = single_df.drop(columns=['Unnamed: 1']) ## commented out to allow for the notebook to run as a whole
    #                                                    ## to see the error, you need to uncomment it

    print(single_df.head())


    cleaned_dfs.append(single_df)
# Out:
#                                       Rechnung\r2007  Voranschlag\r2008
# 0  609 422 232.71\r\r\r\r222 319 590.30\r\r\r2 00...                NaN  \
# 1  117 742 875.05\r\r\r63 572 285.75\r\r\r10 707 ...                NaN
#
#    Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 0    NaN             NaN                                NaN
# 1    NaN             NaN                                NaN
# <class 'pandas.core.frame.DataFrame'>
#   Rechnung\r2007 609 422 232.71\r\r\r\r222 319 590.30\r\r\r2 002 011.35
# 1  117 742 875.05\r\r\r63 572 285.75\r\r\r10 707 ...                     \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#   Rechnung\r2007 609 422 232.71\r\r\r\r222 319 590.30\r\r\r2 002 011.35
# 1  117 742 875.05\r\r\r63 572 285.75\r\r\r10 707 ...                     \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#                                       Rechnung\r2007  Voranschlag\r2008
# 0  63 663 913.29\r\r4 058 594.39\r33 675 318.90\r...                NaN  \
# 1  21 881.20\r5 397 517.65\r100 266 704.15\r\r\r1...                NaN
#
#    Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 0    NaN             NaN                                NaN
# 1    NaN             NaN                                NaN
# <class 'pandas.core.frame.DataFrame'>
#   Rechnung\r2007 63 663 913.29\r\r4 058 594.39\r33 675 318.90\r\r25 930 000.00\r\r5 419 398.85
# 1  21 881.20\r5 397 517.65\r100 266 704.15\r\r\r1...                                            \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#   Rechnung\r2007 63 663 913.29\r\r4 058 594.39\r33 675 318.90\r\r25 930 000.00\r\r5 419 398.85
# 1  21 881.20\r5 397 517.65\r100 266 704.15\r\r\r1...                                            \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#                                       Rechnung\r2007  Voranschlag\r2008
# 0  611 071 377.55\r250 593 287.35\r230 508 940.70...                NaN  \
# 1  555 605.00\r555 605.00\r40 088 353.83\r542 286...                NaN
#
#    Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 0    NaN             NaN                                NaN
# 1    NaN             NaN                                NaN
# <class 'pandas.core.frame.DataFrame'>
#   Rechnung\r2007 611 071 377.55\r250 593 287.35\r230 508 940.70\r13 048 767.25\r6 434 646.15\r600 933.25
# 1  555 605.00\r555 605.00\r40 088 353.83\r542 286...                                                      \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#   Rechnung\r2007 611 071 377.55\r250 593 287.35\r230 508 940.70\r13 048 767.25\r6 434 646.15\r600 933.25
# 1  555 605.00\r555 605.00\r40 088 353.83\r542 286...                                                      \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#                                       Rechnung\r2007  Voranschlag\r2008
# 0  3 117 430.75\r685 223.85\r2 412 506.90\r19 700...                NaN  \
# 1  525 633.80\r\r1 533 350.07\r1 533 350.07\r89 8...                NaN
#
#    Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 0    NaN             NaN                                NaN
# 1    NaN             NaN                                NaN
# <class 'pandas.core.frame.DataFrame'>
#   Rechnung\r2007 3 117 430.75\r685 223.85\r2 412 506.90\r19 700.00\r947 583.00\r113 216.00\r308 733.20
# 1  525 633.80\r\r1 533 350.07\r1 533 350.07\r89 8...                                                    \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN
#   Rechnung\r2007 3 117 430.75\r685 223.85\r2 412 506.90\r19 700.00\r947 583.00\r113 216.00\r308 733.20
# 1  525 633.80\r\r1 533 350.07\r1 533 350.07\r89 8...                                                    \
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 1                NaN    NaN             NaN                                NaN

# %%
df_tabula_08[0].head()
# Out:
#   Rechnung\r2007 609 422 232.71\r\r\r\r222 319 590.30\r\r\r2 002 011.35
# 0  609 422 232.71\r\r\r\r222 319 590.30\r\r\r2 00...                     \
# 1  117 742 875.05\r\r\r63 572 285.75\r\r\r10 707 ...
#
#    Voranschlag\r2008  Konto  Rechnung\r2008  Abweichung von\rBudget u. Nachtr.
# 0                NaN    NaN             NaN                                NaN
# 1                NaN    NaN             NaN                                NaN

# %% [markdown]
# #### As can be seen, the issue is due to Tabula. The PDFs somehow, do not get read properly. Let's see if it can be fixed. Otherwise this might mean excluding a big chunk of PDFs, which would not allow a proper data analysis and comparison between different years.

# %% [markdown]
# #### The reader.ipynb in the "tabula reading documents" folder is used to get a feeling for how many reports are affected by wrong scanning. Only the datraframes from 2014, 2016 and 2022 seem to have a colum "Unnamed: 1". This is not even a sufficient condition to tell that these three dataframes are read correctly.

# %% [markdown]
# #### The next step is to try out another solution

# %%
# trying out with PyPDF2, that was already imported (added the PdfReader to the import statement) and with the report SG 2008


## reader object
reader = PdfReader("cut reduced 2008 Rechnung.pdf")  # cut reduced 2008 Rechnung.pdf

## finding the page with the "Inhaltsverzeichnis" (table of contents)
number_of_pages = len(reader.pages)
page_ihv = 0

for page_number in range(number_of_pages):

    page = reader.pages[page_number]

    # print(page.extract_text())
    print(repr(page.extract_text()))
# Out:
# 'Rechnung\n2007Voranschlag\n2008Konto Rechnung\n2008Abweichung von \nBudget u. Nachtr.\n9   589 392 548.78  575 287 100  3 A u f w a n d   609 422 232.71   504 933+\n    30 385 600 P    \n    3 244 600 S    \n        \n   212 618 936.90  224 104 700  30 Personalaufwand   222 319 590.30  4 543 010–\n    1 386 000 S    \n    1 371 900 P    \n   2 024 242.15  2 102 200  300 Behörden und Kommissionen  2 002 011.35   105 689–\n     5 500 S    \n   111 351 725.65  118 530 700  301 Löhne  117 742 875.05  2 491 625–    1 019 600 S    \n     684 200 P    \n   64 014 100.65  63 941 800  302 Löhne der Lehrkräfte  63 572 285.75  1 140 714–     687 700 P    \n     83 500 S    \n   10 427 703.85  10 936 400  303 Sozialversicherungsbeiträge  10 707 193.45   229 207–   14 987 267.45  17 467 400  304 Versicherungs- / Sparkassenbeiträge  18 258 719.75   791 320+   1 058 047.10  1 107 800  305 Unfallversicherungsbeiträge  1 071 308.35   36 492–    709 980.05   794 300  306 Dienstkleider und Verpflegungszulagen   832 606.80   70 193–     108 500 S    \n   5 436 505.75  5 884 500  307 Besondere Rentenleistungen  5 233 058.75   651 441–    125 606.95   224 000  308 Entschädigungen für temporäre Arbeitskräfte   117 755.50   106 245–   2 483 757.30  3 115 600  309 Übriger Personalaufwand  2 781 775.55   502 724–     168 900 S    \n          \n 73 935 152.22  81 298 100  31 Sachaufwand   78 870 072.84  4 712 027–\n    1 544 900 S    \n     739 100 P    \n   4 153 580.32  4 921 600  310 Büromaterial und Drucksachen  4 306 884.92   662 515–\n     32 800 S    \n     15 000 P    \n   5 860 750.34  5 713 200  311 Mobilien, Maschinen, Fahrzeuge  6 183 948.27   186 152–     403 000 S    \n     253 900 P    \n   5 999 323.77  6 300 000  312 Wasser, Strom und Heizmaterialien  6 486 956.27   186 956+   7 243 376.53  8 323 200  313 Verbrauchsmaterialien  8 090 863.20   380 637–     138 300 S    \n     10 000 P    \n   17 863 819.21  18 349 400  314 Baulicher Unterhalt  18 106 027.02   665 873–     142 300 S    \n     280 200 P    \n   5 796 606.39  6 331 400  315 Übriger Unterhalt  6 083 637.88   630 662–     180 000 P    \n     202 900 S    \n   3 864 162.75  4 217 400  316 Mieten, Pachten, Benützungskosten  3 981 536.86   429 063–     193 200 S    \n   2 933 843.45  3 084 700  317 Spesenentschädigungen  2 761 571.16   383 429–     60 300 S    \n   19 625 026.67  23 287 100  318 Dienstleistungen und Honorare  22 214 080.76  1 399 519–     326 500 S    \n    594 662.79   770 100  319 Übriger Sachaufwand   654 566.50   161 134–     45 600 S    \n        \n   20 564 052.80  20 210 300  32 Passivzinsen   19 132 137.15  1 078 163–\n   1 334 545.40  1 605 200  321 Passivzinsen auf kurzfristigen Schulden  1 397 964.70   207 235–   11 717 650.95  12 220 800  322 Passivzinsen auf mittel- und langfristigen Schulden  10 899 438.90  1 321 361–   7 511 856.45  6 384 300  323 Passivzinsen auf Sonderrechnungen  6 834 733.55   450 434+        Laufende Rechnung / Aufwand nach Sachgruppen Alle Direktionen'
# 'Rechnung\n2007Voranschlag\n2008Konto Rechnung\n2008Abweichung von \nBudget u. Nachtr.\n10   58 831 006.28  50 320 300  33 Abschreibungen   63 663 913.29   586 387–\n    13 930 000 P    \n   4 958 994.83  4 949 300  330 Abschreibungen auf dem Finanzvermögen  4 058 594.39   890 706–\n   31 650 011.45  33 371 000  331 Abschreibungen auf dem Verwaltungsvermögen,  33 675 318.90   304 319+      ordentliche     22 222 000.00  12 000 000  332 Abschreibungen auf dem Verwaltungsvermögen,  25 930 000.00 \n    13 930 000 P  zusätzliche          \n   5 545 258.75  5 190 000  35 Entschädigungen an Gemeinwesen   5 419 398.85   229 399+\n    67 018.50   24 000  351 Entschädigungen an Gemeinwesen auf   21 881.20   2 119–     kantonaler Ebene\n   5 478 240.25  5 166 000  352 Entschädigungen an Gemeinwesen auf  5 397 517.65   231 518+     kommunaler Ebene\n           \n107 955 073.63  102 242 800  36 Eigene Beiträge   100 266 704.15  3 634 396–\n     313 700 S    \n    1 344 600 P    \n   21 023 037.40  13 840 500  361 Beiträge an Institutionen auf kantonaler Ebene  13 992 580.15   152 080+\n    86 489.50   95 000  362 Beiträge an Institutionen auf kommunaler Ebene   79 117.90   15 882–   3 971 618.60  4 499 000  363 Beiträge an eigene Unternehmungen  4 705 827.60   62 772–     63 000 S    \n     206 600 P    \n   3 260 767.40  3 163 200  364 Beiträge an gemischtwirtschaftliche  3 586 150.90   50 049–     40 000 S  Unternehmungen       433 000 P    \n   21 284 941.23  25 563 800  365 Beiträge an private Institutionen  24 803 706.29  1 675 794–     210 700 S    \n     705 000 P    \n   58 148 219.50  54 881 300  366 Beiträge an private Haushalte  52 896 321.31  1 984 979–    180 000.00   200 000  367 Beiträge ins Ausland   203 000.00   3 000+        \n   1 216 530.40   775 000  37 Durchlaufende Beiträge    947 583.00   172 583+\n   1 109 333.40   670 000  370 Durchlaufende Beiträge auf Bundesebene   834 367.00   164 367+    107 197.00   105 000  376 Durchlaufende Beiträge an private Haushalte   113 216.00   8 216+          \n 17 370 368.82  6 593 600  38 Einlagen in Spezialfinanzierungen   28 929 697.68  9 336 098+\n    13 000 000 P  und Stiftungen   \n   17 370 368.82  6 593 600  380 Einlagen in Spezialfinanzierungen und Stiftungen  28 929 697.68  9 336 098+\n    13 000 000 P    \n        \n   91 356 168.98  84 552 300  39 Interne Verrechnungen   89 873 135.45  5 320 835+\n   47 145 728.53  44 081 700  390 Intern verrechneter Aufwand  46 146 012.73  2 064 313+   2 246 986.35  2 420 500  391 Intern verrechneter Aufwand  2 277 838.90   142 661–    12 260.85   26 000  392 Intern verrechneter Aufwand    26 000–    708 328.60   12 000  393 Intern verrechneter Aufwand   12 000.00 \n    662 940.00   700 000  394 Intern verrechneter Aufwand   702 356.00   2 356+   12 024 845.40  12 116 400  396 Intern verrechnete Zinsen  12 695 156.05   578 756+   2 501 085.70  2 531 700  397 Intern verrechneter Aufwand  2 310 904.20   220 796–   26 053 993.55  22 664 000  398 Intern verrechnete Abschreibungen  25 728 867.57  3 064 868+        Laufende Rechnung / Aufwand nach Sachgruppen Alle Direktionen'
# 'Rechnung\n2007Voranschlag\n2008Konto Rechnung\n2008Abweichung von \nBudget u. Nachtr.\n11   593 091 411.53  571 976 100  4 E r t r a g   611 071 377.55  39 095 278+\n      \n  \n   253 442 579.37  238 590 000  40 Steuern   250 593 287.35  12 003 287+\n   232 375 066.67  219 580 000  400 Einkommens- und Vermögenssteuern  230 508 940.70  10 928 941+   12 865 969.95  13 100 000  402 Grundsteuern  13 048 767.25   51 233–   6 012 224.35  5 700 000  404 Vermögensverkehrssteuern  6 434 646.15   734 646+   2 189 318.40   210 000  406 Besitz- und Aufwandsteuern   600 933.25   390 933+        \n    553 136.30   490 000  41 Konzessionen    555 605.00   65 605+\n    553 136.30   490 000  410 Konzessionen   555 605.00   65 605+        \n   36 595 827.86  35 121 500  42 Vermögenserträge   40 088 353.83  4 966 854+\n    543 105.11   240 200  420 Vermögenserträge von Banken   542 286.38   302 086+   3 740 470.70   850 300  421 Vermögenserträge aus Guthaben  3 121 480.75  2 271 181+   1 187 432.10  1 030 200  422 Vermögenserträge aus Anlagen des  1 111 008.55   80 809+     Finanzvermögens\n   12 166 090.95  12 120 200  423 Liegenschaftserträge des Finanzvermögens  13 026 421.85   906 222+   2 476 700.80  2 000 000  424 Buchgewinne auf Anlagen des Finanzvermögens  2 457 414.95   457 415+   5 331 143.50  4 600 000  425 Vermögenserträge aus Darlehen des  5 357 833.20   757 833+     Verwaltungsvermögens\n   7 665 194.50  9 170 200  426 Vermögenserträge aus Beteiligungen des  9 170 222.50    23+      Verwaltungsvermögens     3 414 762.10  3 518 200  427 Liegenschaftserträge des Verwaltungsvermögens  3 692 753.00   174 553+    70 928.10  1 592 200  429 Übrige Vermögenserträge  1 608 932.65   16 733+        \n   110 745 218.03  108 471 400  43 Entgelte   120 009 121.46  11 537 721+\n   6 529 803.51  6 220 000  430 Ersatzabgaben  6 974 279.19   754 279+\n   11 825 740.42  11 669 600  431 Gebühren für Amtshandlungen  12 407 579.78   737 980+   1 489 634.00  1 540 000  432 Spital- und Heimtaxen, Kostgelder  1 521 858.00   18 142–   1 411 461.55  1 327 000  433 Schulgelder  1 337 728.85   10 729+   50 377 754.52  50 246 200  434 Benützungsgebühren und Dienstleistungen  57 221 339.79  6 975 140+   1 910 452.90  1 611 200  435 Verkäufe  1 835 496.60   224 297+   30 432 187.18  29 657 400  436 Rückerstattungen  32 692 933.88  3 035 534+   4 123 920.00  4 118 000  437 Bussen  3 910 707.93   207 292–   2 343 830.95  1 605 500  438 Eigenleistungen für Investitionen  1 802 537.80   197 038+    300 433.00   476 500  439 Übrige Entgelte   304 659.64   171 840–        \n   52 675 051.19  68 592 000  44 Beiträge ohne Zweckbindung   73 899 147.03  5 307 147+\n   50 638 811.19  44 758 000  441 Anteile an Kantonseinnahmen  50 048 247.03  5 290 247+   2 000 000.00  23 834 000  444 Kantonsbeiträge  23 850 900.00   16 900+    36 240.00   445 Gemeindebeiträge  \n        \n   32 271 230.55  30 413 300  45 Rückerstattungen von Gemeinwesen   30 454 363.61   41 064+\n   2 199 413.75  1 042 000  450 Rückerstattungen des Bundes  1 052 984.05   10 984+   26 069 433.55  26 233 500  451 Rückerstattungen des Kantons  25 742 102.76   491 397–   4 002 383.25  3 137 800  452 Rückerstattungen von Gemeinden  3 659 276.80   521 477+        Laufende Rechnung / Ertrag nach Sachgruppen Alle Direktionen'
# 'Rechnung\n2007Voranschlag\n2008Konto Rechnung\n2008Abweichung von \nBudget u. Nachtr.\n12   13 630 822.10  3 359 500  46 Beiträge für eigene Rechnung   3 117 430.75   242 069–\n   1 467 184.60   728 300  460 Beiträge des Bundes   685 223.85   43 076–\n   12 132 737.50  2 591 200  461 Beiträge des Kantons  2 412 506.90   178 693–    30 900.00   40 000  462 Beiträge von Gemeinden   19 700.00   20 300–        \n   1 216 530.40   775 000  47 Durchlaufende Beiträge    947 583.00   172 583+\n    107 197.00   105 000  471 Durchlaufende Beiträge auf kantonaler Ebene   113 216.00   8 216+    332 294.80   320 000  473 Durchlaufende Beiträge von eigenen   308 733.20   11 267–     Unternehmungen\n    777 038.60   350 000  475 Durchlaufende Beiträge von privaten Institutionen   525 633.80   175 634+        \n    604 846.75  1 611 100  48 Entnahmen aus Spezialfinanzierungen   1 533 350.07   77 750–\n     und Stiftungen\n    604 846.75  1 611 100  480 Entnahmen aus Spezialfinanzierungen  1 533 350.07   77 750–\n     und Stiftungen\n        \n   91 356 168.98  84 552 300  49 Interne Verrechnungen   89 873 135.45  5 320 835+\n   48 572 366.33  45 673 800  490 Intern verrechneter Ertrag  47 536 806.33  1 863 006+    805 501.25   828 400  491 Intern verrechneter Ertrag   856 339.35   27 939+    27 108.15   26 000  492 Intern verrechneter Ertrag   30 705.95   4 706+    708 328.60   12 000  493 Intern verrechneter Ertrag   12 000.00 \n    662 940.00   700 000  494 Intern verrechneter Ertrag   702 356.00   2 356+   12 024 845.40  12 116 400  496 Intern verrechnete Zinsen  12 695 156.05   578 756+   2 501 085.70  2 531 700  497 Intern verrechneter Ertrag  2 310 904.20   220 796–   26 053 993.55  22 664 000  498 Intern verrechnete Abschreibungen  25 728 867.57  3 064 868+       \n       \n       \n       \n       Laufende Rechnung / Ertrag nach Sachgruppen Alle Direktionen'

# %%
df_tabula = read_pdf("cut reduced 2016 Rechnung.pdf", pages="all")

# %%
df_tabula[1]
# Out:
#                                       Rechnung\r2015  Voranschlag\r2016
# 0  40 169 875.24\r3 074 341.83\r37 337 464.16\r24...                NaN  \
# 1  8 655 864.97\r144 852 556.39\r\r\r\r35 009 206...                NaN
#
#    Konto  Rechnung\r2016  Abweichung von\rBudget u. Nachtr.
# 0    NaN             NaN                                NaN
# 1    NaN             NaN                                NaN
